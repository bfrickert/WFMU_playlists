# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import time
import datetime
import sys

def scrapeWFMUPlaylist(url, border_width=1):
    response = requests.get(url)

    soup = BeautifulSoup(response.text)
    tables = soup.findAll("table", {'border':'{0}'.format(border_width)})
    rows = tables[0].findAll('tr')
    print(rows)
    values = []
    try:
        dt = soup.findAll(text=re.compile('Playlist for (.*)$'))
        mdt = re.match('Playlist for (.*)$', dt[0].strip(), re.M|re.I)
        str_dt = '%s %s, %s' % (re.match('([0-3][0-9]) (\w*) (20[0-1][0-9])',mdt.group(1)).group(2), re.match('([0-3][0-9]) (\w*) (20[0-1][0-9])',mdt.group(1)).group(1), re.match('([0-3][0-9]) (\w*) (20[0-1][0-9])',mdt.group(1)).group(3))
        fdt = "%s/%s/%s" % (time.strptime(str_dt, '%B %d, %Y')[1], time.strptime(str_dt, '%B %d, %Y')[2], time.strptime(str_dt, '%B %d, %Y')[0])
    except:
        try:
            dt = soup.findAll(text=re.compile('([a-zA-Z] [0-9]+, 20[0-1][0-9]):'))
            print(dt[0])
            mdt = re.match('(.*):', dt[0].strip(), re.M|re.I)
            print(mdt.group(1))
            dt_struct = datetime.datetime.strptime(mdt.group(1), '%B %d, %Y')
            fdt = dt_struct.strftime('%m/%d/%Y')
            print(fdt)
        except:
            dt = soup.findAll(text=re.compile('([a-zA-Z] [0-9]+, 20[0-1][0-9])'))
            mdt = re.match('(.*)', dt[2].replace('\n',' ').strip(), re.M|re.I)
            dt_struct = datetime.datetime.strptime(mdt.group(1), '%B %d, %Y')
            fdt = dt_struct.strftime('%m/%d/%Y')
    for row in rows:
        cells = row.findAll('td')

        if len(cells) >= 4:
            try:
                song = cells[1].find("font").find(text=True).strip().encode('ascii', 'ignore')
                artist = cells[0].find("font").find(text=True).strip().encode('ascii', 'ignore')
            except:
                song = 'FAIL'
                artist = 'FAIL'
            values.append([artist, song, fdt])

    df = pd.DataFrame(values)
    return df

df = pd.DataFrame()
url_df = pd.read_csv('data/SW/playlists.tsv', sep='\t')

# %%
urls = [row[1] for index, row in url_df.iterrows()]
i = 0
for url in urls[13:14]:
    try:
        i += 1
        print str(i) + url
        df = df.append(scrapeWFMUPlaylist(url))
        print(df)
    except:
        print('fak')
        pass
print(df)
df.columns = ['artist','song','date']
df.to_csv('data/SW/songs.tsv', sep='\t')
# Out:
# 1http://www.wfmu.org/playlists/shows/64334
# [<tr>
# <th class="song">Artist</th>
# <th class="song">Track</th>
# <th class="song">Album</th>
# <th class="song">Label</th>
# <th class="song">Year</th>
# <th class="song">Comments</th>
# <th class="song"><font size="-1">Approx. start time</font></th>
# </tr>, <tr>
# <td class="song">
# <font size="-1">Unheard Indonesia</font>
# </td>
# <td class="song">
# <font size="-1">(exc)
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-1562056">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=1562056&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">Pencak Silat Situbondo, East Java</font>
# </td>
# <td class="song">
# <font size="-1">Psychic Sounds</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td class="song">
# <font size="-1">w/ Arrington de Dionyso</font>
# </td>
# <td align="center" class="song">
#
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">The Ordinaires</font>
# </td>
# <td class="song">
# <font size="-1">Brenda
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-1562060">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=1562060&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">One</font>
# </td>
# <td class="song">
# <font size="-1">Bar None</font>
# </td>
# <td class="song">
# <font size="-1">1989</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 0:01:29 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'0:01:29',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">Oneida</font>
# </td>
# <td class="song">
# <font size="-1">Caesar's Column - White Pants Remix
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-1562061">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=1562061&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">Caeser's Column</font>
# </td>
# <td class="song">
# <font size="-1">Rough Trade</font>
# </td>
# <td class="song">
# <font size="-1">2003</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 0:04:49 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'0:04:49',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">The Idiot Orchestra</font>
# </td>
# <td class="song">
# <font size="-1">Big City
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-1552036">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=1552036&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">Liquid Idiot / The Idiot Orchestra</font>
# </td>
# <td class="song">
# <font size="-1">Superior Viaduct</font>
# </td>
# <td class="song">
# <font size="-1">1980</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 0:11:21 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'0:11:21',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">Thiago França: Space Charanga</font>
# </td>
# <td class="song">
# <font size="-1">Moaciria
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-1562064">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=1562064&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">R.A.N.</font>
# </td>
# <td class="song">
# <font size="-1">Goma Gringa Discos</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 0:13:50 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'0:13:50',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">Théâtre du Chêne Noir d'Avignon</font>
# </td>
# <td class="song">
# <font size="-1">Hey...
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-1562065">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=1562065&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">Chant Pour Le Delta La Lune Et Le Soleil</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td class="song">
# <font size="-1">1976</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 0:19:13 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'0:19:13',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">Faceless</font>
# </td>
# <td class="song">
# <font size="-1">The Man with the Flashlight
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-1562066">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=1562066&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">Fake (split LP w/ Otto Ketrol)</font>
# </td>
# <td class="song">
# <font size="-1">Hasch Platten</font>
# </td>
# <td class="song">
# <font size="-1">1983</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 0:30:47 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'0:30:47',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">Wax Pancake</font>
# </td>
# <td class="song">
# <font size="-1">Hotline Bling
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-1562067">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=1562067&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">https://soundcloud.com/waxpancake/sets/mp3-to-midi-and-back</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td class="song">
# <font size="-1">more info <a href="https://exit.sc/?url=http%3A%2F%2Fwaxy.org%2F2015%2F12%2Fif_drake_was_born_a_piano%2F">here</a></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 0:33:41 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'0:33:41',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song" colspan="8">
# <a name="9"> </a>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">Aaron Dilloway</font>
# </td>
# <td class="song">
# <font size="-1">Tr B2
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-1562075">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=1562075&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">Psychic Driving Tapes</font>
# </td>
# <td class="song">
# <font size="-1">The Trilogy Tapes</font>
# </td>
# <td class="song">
# <font size="-1">2009</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 0:49:49 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'0:49:49',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">Capra Informis</font>
# </td>
# <td class="song">
# <font size="-1">Womb of the Wild
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-1562078">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=1562078&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">Womb of The Wild EP</font>
# </td>
# <td class="song">
# <font size="-1">Rocket Recordings</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 1:01:03 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'1:01:03',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">Empire</font>
# </td>
# <td class="song">
# <font size="-1">Expensive Sound
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-1366430">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=1366430&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">Expensive Sound</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td class="song">
# <font size="-1">1981</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 1:05:59 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'1:05:59',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">Armed Force</font>
# </td>
# <td class="song">
# <font size="-1">Popstar
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-1562081">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=1562081&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">V/a, Greater Manchester Punk 1977-81</font>
# </td>
# <td class="song">
# <font size="-1">Vinyl Revival</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 1:09:59 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'1:09:59',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">Pere Ubu</font>
# </td>
# <td class="song">
# <font size="-1">Blow Daddy-O
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-1562084">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=1562084&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">Dub Housing</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 1:13:07 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'1:13:07',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">Roy Orbison</font>
# </td>
# <td class="song">
# <font size="-1">There Won't Be Many Coming Home
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-1562086">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=1562086&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">sdtk, "The Fastest Guitar Alive"</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 1:16:36 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'1:16:36',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song" colspan="8">
# <a name="16"> </a>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">Ana da Silva</font>
# </td>
# <td class="song">
# <font size="-1">The Lighthouse
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-765560">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=765560&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">The Lighthouse</font>
# </td>
# <td class="song">
# <font size="-1">Chicks On Speed Records</font>
# </td>
# <td class="song">
# <font size="-1">2004</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 1:28:48 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'1:28:48',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">The Residents</font>
# </td>
# <td class="song">
# <font size="-1">Six Things To A Cycle (exc)
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-1562091">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=1562091&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">Fingerprince</font>
# </td>
# <td class="song">
# <font size="-1">Ralph</font>
# </td>
# <td class="song">
# <font size="-1">1976</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 1:32:00 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'1:32:00',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">I Know I'm An Alien</font>
# </td>
# <td class="song">
# <font size="-1">Life In The City (Noise Rock Theme)
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-1562094">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=1562094&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">I know Im An Alien And I Want To Go Home Sometimes But Then I Remember That I Gotta Try And Understand You</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 1:42:21 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'1:42:21',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">David Bowie</font>
# </td>
# <td class="song">
# <font size="-1">The Wedding Song
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-1562097">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=1562097&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">Black Tie White Noise</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td class="song">
# <font size="-1">1993</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 1:46:32 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'1:46:32',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">Quintette Guineenne</font>
# </td>
# <td class="song">
# <font size="-1">Cisse Massane
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-1562100">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=1562100&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">V/a, Musique Sans Paroles</font>
# </td>
# <td class="song">
# <font size="-1">Stern's Africa</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 1:50:47 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'1:50:47',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">Bianca</font>
# </td>
# <td class="song">
# <font size="-1">La Fourmi
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-1562101">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=1562101&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">V/a, France Chebran: French Boogie 1981-1985</font>
# </td>
# <td class="song">
# <font size="-1">Born Bad</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 1:55:36 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'1:55:36',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">The Other Side</font>
# </td>
# <td class="song">
# <font size="-1">Cornbread Part 1
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-1562103">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=1562103&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">(Don't Look Back) Behind The Shack</font>
# </td>
# <td class="song">
# <font size="-1">Desco</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 1:59:03 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'1:59:03',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song" colspan="8">
# <a name="24"> </a>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">Nochteff</font>
# </td>
# <td class="song">
# <font size="-1">Seraphin
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-1562107">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=1562107&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td class="song">
# <font size="-1">Tomas Nochteff of Mueran Humanos</font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 2:08:42 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'2:08:42',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">Yoko Ono</font>
# </td>
# <td class="song">
# <font size="-1">Don't Count The Waves
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-752210">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=752210&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">Fly</font>
# </td>
# <td class="song">
# <font size="-1">Apple</font>
# </td>
# <td class="song">
# <font size="-1">1971</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 2:20:34 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'2:20:34',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">Maurizio Bianchi</font>
# </td>
# <td class="song">
# <font size="-1">OPEA Part 2 (exc)
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-1562118">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=1562118&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">cmrs/opea</font>
# </td>
# <td class="song">
# <font size="-1">Urashima</font>
# </td>
# <td class="song">
# <font size="-1">1980</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 2:25:52 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'2:25:52',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">Bourbonese Qualk</font>
# </td>
# <td class="song">
# <font size="-1">Dereliction
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-1562126">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=1562126&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">Hope</font>
# </td>
# <td class="song">
# <font size="-1">Recloose Organisation</font>
# </td>
# <td class="song">
# <font size="-1">1984</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 2:31:00 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'2:31:00',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">Dirty Beaches</font>
# </td>
# <td class="song">
# <font size="-1">Like The Ocean We Part
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-1562131">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=1562131&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">live on my show, Sept 7 2013</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td class="song">
# <font size="-1">get 'er <a href="http://freemusicarchive.org/music/Dirty_Beaches/">'ere</a> -- yay FMA!</font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 2:35:33 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'2:35:33',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">Vincent Over the Sink</font>
# </td>
# <td class="song">
# <font size="-1">Mektoub
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-923927">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=923927&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">22 Coloured Bull Terriers</font>
# </td>
# <td class="song">
# <font size="-1">Another Dark Age</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 2:40:34 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'2:40:34',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">Amen Dunes</font>
# </td>
# <td class="song">
# <font size="-1">Spirits Are Parted
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-1562136">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=1562136&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">Love</font>
# </td>
# <td class="song">
# <font size="-1">Sacred Bones</font>
# </td>
# <td class="song">
# <font size="-1">2014</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 2:44:05 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'2:44:05',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">Yo La Tengo</font>
# </td>
# <td class="song">
# <font size="-1">The Lie And How We Told It
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-901691">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=901691&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">I Can Hear the Heart Beating as One</font>
# </td>
# <td class="song">
# <font size="-1">Matador</font>
# </td>
# <td class="song">
# <font size="-1">1997</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 2:47:56 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'2:47:56',0,'');
# </script>)
# </font>
# </td>
# </tr>, <tr>
# <td class="song">
# <font size="-1">Leyland Kirby</font>
# </td>
# <td class="song">
# <font size="-1">Sadly The Future Is No Longer What It Was
# </font>
# <span class="KDBFavIcon KDBsong" id="KDBsong-1384028">
# <a href="https://wfmu.org/auth.php?a=fav_icon_clicked&amp;type=song&amp;id=1384028&amp;page_type=playlist&amp;page_id=64334&amp;r=http%3A%2F%2Fwfmu.org%2Fplaylists%2Fshows%2F64334" onclick="KDBFav.fav_icon_clicked(event, this.parentNode);" title="Click for options"><img alt="Options" border="0" src="/Gfx/star_empty_2.png"/></a>
# </span>
# </td>
# <td class="song">
# <font size="-1">Sadly the Future is No Longer What It Was</font>
# </td>
# <td class="song">
# <font size="-1">History Always Favours The Winners</font>
# </td>
# <td class="song">
# <font size="-1">2009</font>
# </td>
# <td class="song">
# <font size="-1"></font>
# </td>
# <td align="center" class="song">
# <font size="-1">
# 2:51:06 (<script type="text/javascript">
# accuflashlink('64334','136417',2,'2:51:06',0,'');
# </script>)
# </font>
# </td>
# </tr>]
#
# December 28, 2015: Hey...
#
# December 28, 2015
# 12/28/2015
#                                0                                          1  \
# 0              Unheard Indonesia                                      (exc)
# 1                 The Ordinaires                                     Brenda
# 2                         Oneida        Caesar's Column - White Pants Remix
# 3            The Idiot Orchestra                                   Big City
# 4   Thiago Frana: Space Charanga                                   Moaciria
# 5   Thtre du Chne Noir d'Avignon                                     Hey...
# 6                       Faceless                The Man with the Flashlight
# 7                    Wax Pancake                              Hotline Bling
# 8                 Aaron Dilloway                                      Tr B2
# 9                 Capra Informis                           Womb of the Wild
# 10                        Empire                            Expensive Sound
# 11                   Armed Force                                    Popstar
# 12                      Pere Ubu                               Blow Daddy-O
# 13                   Roy Orbison            There Won't Be Many Coming Home
# 14                  Ana da Silva                             The Lighthouse
# 15                 The Residents                Six Things To A Cycle (exc)
# 16           I Know I'm An Alien        Life In The City (Noise Rock Theme)
# 17                   David Bowie                           The Wedding Song
# 18           Quintette Guineenne                              Cisse Massane
# 19                        Bianca                                  La Fourmi
# 20                The Other Side                           Cornbread Part 1
# 21                      Nochteff                                   Seraphin
# 22                      Yoko Ono                      Don't Count The Waves
# 23              Maurizio Bianchi                          OPEA Part 2 (exc)
# 24              Bourbonese Qualk                                Dereliction
# 25                 Dirty Beaches                     Like The Ocean We Part
